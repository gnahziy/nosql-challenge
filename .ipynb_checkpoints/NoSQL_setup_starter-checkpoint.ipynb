# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `mongoimport --type json -d uk_food -c establishments --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'autosaurus', 'classDB', 'config', 'epa', 'fruits_db', 'gardenDB', 'local', 'met', 'petsitly_marketing', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'The Pines Garden',
#  'AddressLine2': 'Beach Road',
#  'AddressLine3': 'St Margarets Bay',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Tea Room',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4587.362402580997,
#  'FHRSID': 551803,
#  'LocalAuthorityBusinessID': 'PI/000070948',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT15 6DZ',
#  'RatingDate': '2021-08-17T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64b48e083a1827b36b4b923e'),
#  'geocode': {'latitude': '51.148133', 'longitude': '1.383298'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/551803',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)

# %%
# Check that the new restaurant was inserted
pprint(db.establishments.find_one({"BusinessName": "Penang Flavours"}))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64b48e318ec4d996e4250cde'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': 'Restaurant/Cafe/Canteen'}
fields = {'BusinessTypeID': 1, 'BusinessType': 1}

results = list(establishments.find(query, fields))

pprint(results)
# Out:
# [{'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b923e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9240')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9242')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9243')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9245')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9246')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9247')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9248')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b924c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b924e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9250')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9252')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b925a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b925d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9261')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b926d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b926f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9271')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9273')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9274')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9275')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b927c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b927d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b927f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9280')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9282')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9286')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9288')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b928b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b928c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b928e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b928f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9291')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9292')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9295')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9296')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92a0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92a1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92aa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92ab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92ae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92af')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92b3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92b6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92be')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92bf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92c2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92c8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92cb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92d2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92d8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92d9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92de')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92e3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92e9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92ee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92f7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92f8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b92fd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9303')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9306')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9308')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9309')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b930e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9312')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9314')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b931a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9329')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b932b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b932c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b933a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b933b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b933d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9340')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9346')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b934a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9350')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9351')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b935b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b935d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b935e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9365')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9367')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b936a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9373')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9377')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9379')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b937a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b937e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9380')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9384')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9386')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9387')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9389')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b938b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b938c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b938d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9390')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9391')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9392')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9394')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9395')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b939c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b939d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93a8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93a9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93ac')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93ae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93af')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93b9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93ba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93bb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93bc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93c0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93c2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93c8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93c9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93d8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93df')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93e0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93e8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93e9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93ee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93f2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b93f4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9403')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9404')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9406')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9409')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b940a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b940c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9411')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9420')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b942d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9431')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b943b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9458')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9461')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9464')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9466')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9467')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b946a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9486')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b948d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94a3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94a9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94b2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94b5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94b6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94ba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94d8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94e1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94e3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94e5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94f1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94f2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94f4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b94fb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9504')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9507')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9513')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9518')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9519')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b951c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b951e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9522')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b952f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9531')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9536')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9539')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9545')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b954e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9551')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9554')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9556')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9558')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b955a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b956a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b956f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9573')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b957a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b957b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b957c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9580')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9582')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9584')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9586')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9588')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9589')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9590')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9591')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9594')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9599')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b959b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b959c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b959e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95a2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95ab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95ac')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95ae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95b2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95b4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95b5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95bc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95c1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95c3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95c5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95c9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95d1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95d2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95d4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95d7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95d8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95de')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95e0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95f2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95f5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95f6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95fb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b95fe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9601')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9603')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9609')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b960a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b960b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b960c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b960d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b960e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9610')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9613')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9617')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9618')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b961a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9624')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b962a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b962b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b962c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b962d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9632')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9635')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9636')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9637')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b963a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b963c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b963f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9645')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9646')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9648')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b964a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9650')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b965a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b965e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9676')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9678')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b967f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9680')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9681')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9685')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9689')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b969e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96a3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96a6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96a8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96ab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96b6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96b9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96ba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96bb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96bc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96be')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96c0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96c1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96c3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96d7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96d8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96db')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96dd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96de')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96df')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96e0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96e2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96e3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96e6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96e7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96ea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96ee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96ef')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96f6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96fa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96fb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96fc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b96fe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9701')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9703')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9704')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9708')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b970f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9711')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9712')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9714')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9716')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9718')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9721')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9724')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9725')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b972c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b972d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9733')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9735')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9737')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9738')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9740')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9747')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b974d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9751')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9754')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9757')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9759')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b975f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9760')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9768')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b976f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9770')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9771')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9773')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9774')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9775')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b977f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9780')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9783')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9785')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b978a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b978e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9792')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9794')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9798')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9799')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b979a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b979b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b979c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b979e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b979f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97a1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97a2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97a3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97a5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97a8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97a9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97aa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97ae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97af')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97b1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97b3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97b4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97b6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97b9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97bb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97c5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97c8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97c9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97cb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97d2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97d3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97d7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97da')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97df')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97e0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97e2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97e7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b97f7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9800')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9808')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b980f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9812')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9817')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e083a1827b36b4b9818')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
# ...
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2b94')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2b96')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2b99')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2b9d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2b9f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2ba2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2baa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bad')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bb3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bb4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bb5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bb6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bb7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bbd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bc0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bc1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bc2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bc3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bc5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bc8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bc9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bcb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bd0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bd2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bd6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bd8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bda')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bdb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bdc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2be0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2be2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bf0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bf4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bf5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bfa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2bfd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c06')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c07')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c08')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c0a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c11')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c23')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c35')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c39')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c3f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c42')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c43')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c46')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c4a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c4c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c4d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c4f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c50')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c55')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c5b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c65')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c69')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c73')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c77')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c7f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c81')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c85')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c87')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c8e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c90')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c92')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c93')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c96')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c97')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2c9d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2caf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cbc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cc5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cc6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2ccb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2ccf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cd2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cd9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cdd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2ce1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2ce3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cef')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cf0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cf1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cf3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cf5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cf8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cf9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cfa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cfe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2cff')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d01')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d05')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d06')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d07')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d08')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d09')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d0a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d0b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d0c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d0d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d0f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d11')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d17')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d18')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d1d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d1e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d20')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d21')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d22')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d29')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d2c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d2f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d35')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d3f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d44')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d45')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d49')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d4b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d4d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d5b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d63')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d65')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d6d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d78')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d80')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d84')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d86')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d89')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d90')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d91')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('64b48e0f3a1827b36b4c2d9e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '',
#   '_id': ObjectId('64b48e318ec4d996e4250cde')}]

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
db.establishments.update_one(
    {'BusinessName': 'Penang Flavours'},
    {'$set': 
         {'BusinessTypeID': 1}
     }
)

# %%
# Confirm that the new restaurant was updated
pprint(db.establishments.find_one({"BusinessName": "Penang Flavours"}))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64b48e318ec4d996e4250cde'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
query = {'LocalAuthorityName': 'Dover'}

print(establishments.count_documents(query))
# Out:
# 994

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many(query)

# %%
# Check if any remaining documents include Dover
pprint(db.establishments.find_one({'LocalAuthorityName': 'Dover'}))
# Out:
# None

# %%
# Check that other documents remain with 'find_one'
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64b48e083a1827b36b4b9522'),
#  'geocode': {'latitude': '51.083812', 'longitude': '1.195625'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
establishments.update_many({},[{'$set':{"geocode.longitude": {'$toDouble': "$geocode.longitude"},
                                       "geocode.latitude": {'$toDouble': "$geocode.latitude"}
                                        }
                                }]
                            )

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({},[{'$set':{"RatingValue": {'$toInt': "$RatingValue"}}}])

# %%
# Check that the coordinates and rating value are now numbers
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4591.765489457773,
#  'FHRSID': 1043695,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6BL',
#  'RatingDate': '2018-04-04T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('64b48e083a1827b36b4b9522'),
#  'geocode': {'latitude': 51.083812, 'longitude': 1.195625},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}}
